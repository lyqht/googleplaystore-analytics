# %% [markdown]
# # Preliminary Naive Bayes Model for Sentiment Polarity

# %% [markdown]
# Import necessary dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
tqdm.pandas()

# For Tokenizing
import re
import string
import itertools
from spellchecker import SpellChecker
from contractions import contractions_dict

from nltk import download, word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer

# For Text Classification
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment import SentimentAnalyzer
from nltk.corpus import subjectivity
from nltk.classify import NaiveBayesClassifier

# %% [markdown]
# Download Necessary Corpus for tokenizer, and sentiment analyzers to work.

# %%
download('punkt')
download('stopwords')
download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /home/lyqht/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/lyqht/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/lyqht/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ## The Dataset

# %% [markdown]
# Import the dataset and rename some columns

# %%
df = pd.read_csv("../data/googleplaystore_user_reviews.csv")
df.rename(columns = {'Translated_Review':'Review'}, inplace=True)
df.sample(4)
# Out:
#                                App  \
# 13162           Battlelands Royale
# 271                           11st
# 40425  Episode - Choose Your Story
# 14950      BioLife Plasma Services
#
#                                                   Review Sentiment  \
# 13162  This game excellent mechanics, little bugs, ni...  Positive
# 271    Open Market Revolution A section of the Helo-S...  Positive
# 40425         love game, I dont get anymore free passes.  Positive
# 14950  This supposed easy right?? In land "smart" tec...  Positive
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 13162            0.327500                0.755000
# 271              0.166667                0.500000
# 40425            0.166667                0.600000
# 14950            0.245000                0.542024

# %% [markdown]
# ## Terminology
# Source of definitions: Bing Liu. Sentiment Analysis and Opinion Mining, Morgan & Claypool Publishers, May 2012
# - Sentiment Polarity: Can be split into rational or emotional sentiment. Hence resulting in the common design of 5 sentiment ratings.
#     - emotional negative (-2)
#     - rational negative (-1)
#     - neutral (0): In practice, neutral often means no opinion or sentiment expressed.
#     - rational positive (+1)
#     - emotional positive (+2)
# - Sentiment Subjectivity: Subjective sentences expresses some personal feelings, views, or beliefs. They may not express any sentiment.

# %% [markdown]
# We see that the original dataset also has labels of the sentiment level, polarity and subjectivity by the original author.
# We will build our own model then compare the values to the values in the original dataset for comparison.

# %% [markdown]
# Getting the reviews

# %%
raw_reviews = df["Review"].copy()
raw_reviews.sample(5)
# Out:
# 36843                                                  NaN
# 31631    I can't believe amazing add stuff it'll great ...
# 61265                                                  NaN
# 60015                                                 Nice
# 13672                                                  NaN
# Name: Review, dtype: object

# %% [markdown]
# # Text Mining

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# We will drop NA types in the reviews data, since they do not contain any text. They probably got into the dataset because of imperfect data scraping.

# %%
reviews = raw_reviews.dropna(axis=0)
print("Old data frame length:", len(raw_reviews), "\nNew data frame length:",  
       len(reviews), "\nNumber of rows with at least 1 NA value: ", 
       (len(raw_reviews)-len(reviews)))
# Out:
# Old data frame length: 64295
# New data frame length: 37427
# Number of rows with at least 1 NA value:  26868

# %% [markdown]
# These are the preprocessing steps that we will be doing for every review.
# 1. Converting text to lowercase
# 2. Remove html tags
# 3. Expand Contractions
#     - Dictionary source from : https://github.com/pemagrg1/Text-Pre-Processing-in-Python/blob/master/individual_python_files/contractions.py
# 4. Remove punctuation
# 5. Using NLKT's `PunktSentenceTokenizer` to create tokens
# 6. Word Normalization for Tokens
#     - Correcting mispelled words
#     - Stop word removal
#     - Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
stopword = set(stopwords.words('english'))
spell = SpellChecker()

# %%
# Regex Patterns
html_pattern = re.compile('<[^<]+?>')
lengthening_pattern = re.compile(r"(.)\1{2,}")
contractions_pattern = re.compile('({})'.format('|'.join(contractions_dict.keys())),
                                      flags=re.IGNORECASE | re.DOTALL)

# %%
def remove_html_tags(s):
    global html_pattern
    return html_pattern.sub('', s)
    
def remove_punctuation(s):
    return s.translate(str.maketrans('', '', string.punctuation))    

def expand_contractions(text):
    global contractions_pattern
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contractions_dict.get(match) \
            if contractions_dict.get(match) \
            else contractions_dict.get(match.lower())
        expanded_contraction = expanded_contraction
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

def reduce_lengthening(s):
    global lengthening_pattern
    return lengthening_pattern.sub(r"\1\1", s)

def lemmatize(w):
    global lemmatizer
    return lemmatizer.lemmatize(w)

def normalize(s):
    global spell
    tokens = word_tokenize(s)
    tokens = [lemmatize(word) for word in tokens]
    return tokens

def preprocess(s):
    s = s.lower()
    s = remove_html_tags(s)
    s = expand_contractions(s)
    s = remove_punctuation(s)
    s = reduce_lengthening(s)
    words = normalize(s)
    
    return words

# %% [markdown]
# Testing preprocessing on some reviews

# %%
random_sample = reviews.sample(5)
print("Random Sample")
print(random_sample, "\n")
print("Normalized Tokens produced")
random_sample.progress_apply(preprocess)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Random Sample
# 37456    This game amazing simple problem! TOO MANY ADS...
# 39374                                Nothing new kids love
# 7307                                Keep make game better.
# 55713    The simplicity beautiful. It easy use. The wor...
# 19128    It works got ad problems turn WiFi/3G face pro...
# Name: Review, dtype: object
#
# Normalized Tokens produced
# 100%|██████████| 5/5 [00:01<00:00,  4.07it/s]
# 37456    [this, game, amazing, simple, problem, too, ma...
# 39374                            [nothing, new, kid, love]
# 7307                            [keep, make, game, better]
# 55713    [the, simplicity, beautiful, it, easy, use, th...
# 19128    [it, work, got, ad, problem, turn, wifi3g, fac...
# Name: Review, dtype: object

# %% [markdown]
# Applying preprocessing to all the reviews

# %%
tokens = reviews.apply(preprocess)
processed_df = pd.DataFrame(reviews)
processed_df["Tokens"] = tokens
processed_df.sample(5)
# Out:
#                                                   Review  \
# 5863                                Funny thing happened
# 28928                    Times fast. It's ok, near great
# 21369                                    Just put phone.
# 63201  I love easy use, great locating properties are...
# 30960  I would rate 5 stars seasons big series like F...
#
#                                                   Tokens
# 5863                            [funny, thing, happened]
# 28928              [time, fast, it, is, ok, near, great]
# 21369                                 [just, put, phone]
# 63201  [i, love, easy, use, great, locating, property...
# 30960  [i, would, rate, 5, star, season, big, series,...

# %% [markdown]
# Saving this data for reuse

# %%
processed_df.to_csv("../data/tokenized.csv")

# %% [markdown]
# Visualizing the most common tokens and saving the plot

# %%
fig = plt.figure(figsize = (10,4))
plt.gcf().subplots_adjust(bottom=0.15)

word_counts = list(itertools.chain(*tokens))
freq_dist = FreqDist(word_counts)
freq_dist.plot(30, cumulative=False)

plt.show()
fig.savefig('images/freqDist.png', bbox_inches = "tight")

# %% [markdown]
# Some steps that we did not include for preprocessing that could affect our model:
# - Removing numbers: sometimes in reviews we see that users explain their rationale of giving a specific number of star rating, so we did not want to remove them.
# - Removing chinese reviews and apps: We assumed that China does not have access to Google Playstore, so there will be lesser chinese reviews and apps made in Chinese, but this is certainly not true. However, filtering them out is a hassle atm so we did not do this step.
# - Spell Checking every token: We tried this, but it causes the computation to be taking too long! So we ignore it for now...

# %% [markdown]
# # Modelling

# %% [markdown]
# We will use `VADER SentimentIntensityAnalyzer` for calculating polarity scores for each review. The scoring is computed as following from https://github.com/cjhutto/vaderSentiment:
#
# - The `compound` score is computed by summing the valence scores of each word in the lexicon, adjusted according to the rules, and then normalized to be between -1 (most extreme negative) and +1 (most extreme positive). This is the most useful metric if you want a single unidimensional measure of sentiment for a given sentence. Calling it a 'normalized, weighted composite score' is accurate.
#     - positive sentiment: compound score >= 0.05
#     - neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
#     - negative sentiment: compound score <= -0.05
#
# The `pos`, `neu`, and `neg` scores are ratios for proportions of text that fall in each category (so these should all add up to be 1... or close to it with float operation). These are the most useful metrics if you want multidimensional measures of sentiment for a given sentence.

# %%
analyzer = SentimentIntensityAnalyzer()
def sentiment_polarity(s):
    global analyzer
    polarity_scores = analyzer.polarity_scores(s)
    compound_score = polarity_scores["compound"]
    if compound_score >= 0.5:
        label = "Positive"
    elif compound_score > -0.05 and compound_score < 0.05:
        label = "Neutral"
    else:
        label = "Negative"
    return label, polarity_scores["neu"], polarity_scores["pos"], polarity_scores["neg"]

# %%
df = processed_df
df["Sentiment"], df["Neutral Proportion"], df["Positive Proportion"], df["Negative Proportion"] =  zip(*df["Review"].apply(sentiment_polarity))
df.sample(3)
# Out:
#                                                   Review  \
# 37236                                               Best
# 35953  It nice first days began demanding I upgrade I...
# 45118  This exactly I've looking for! Did preview wat...
#
#                                                   Tokens Sentiment  \
# 37236                                             [best]  Positive
# 35953  [it, nice, first, day, began, demanding, i, up...  Negative
# 45118  [this, exactly, looking, for, did, preview, wa...  Positive
#
#        Neutral Proportion  Positive Proportion  Negative Proportion
# 37236               0.000                1.000                 0.00
# 35953               0.594                0.176                 0.23
# 45118               0.706                0.294                 0.00

# %%
df.to_csv("../data/polarity.csv")

# %% [markdown]
# Now we will classify the reviews based on subjectivity using a `NaiveBayesClassifier`. First, we split the data for testing and training.

# %%
test_size = int(0.2*len(reviews))
x_train = df[:test_size]
x_test = df[test_size:]

# %% [markdown]
# Next, we build a vocabulary consisting of all the words that the training set of reviews have. From the output, you can see that there is still much to be improved upon for the tokens that were obtained despite the preprocessing.

# %%
vocabulary = set(word_counts)
print("Number of words in vocabulary: {}".format(len(vocabulary)))
vocabulary
# Out:
# Number of words in vocabulary: 22322
# {'mae',
#  'sure',
#  'acknowledges',
#  'fastand',
#  'fulfilling',
#  'require',
#  'obama',
#  'stoptheadabuse',
#  'kia',
#  'confidence',
#  'sinc',
#  'wordlists',
#  'lainnya',
#  'newborn',
#  'appreciable',
#  'followed',
#  '15mbps',
#  'wayright',
#  'mohochar',
#  'engrained',
#  'pic',
#  'crosscountry',
#  'nolonger',
#  'victory',
#  'refreshment',
#  'strapped',
#  'destroying',
#  'valavala',
#  'payforeverything',
#  'drove',
#  'poor',
#  'simulate',
#  '2917',
#  'believe',
#  'begginer',
#  'press',
#  'sensationalized',
#  'shade',
#  'acoutered',
#  'wasnt',
#  'syntax',
#  'her',
#  's7',
#  'stocked',
#  'playersyou',
#  'filtersall',
#  'unlimited',
#  'mydiary',
#  'awarding',
#  'unwantedly',
#  'autofilling',
#  'nigeria',
#  'browsing',
#  'print',
#  'internation',
#  'noisy',
#  'abroad',
#  'meaning',
#  'roller',
#  'opposite',
#  'lazers',
#  'ghana',
#  'discusting',
#  'crono',
#  'h2o',
#  'number6157202',
#  'fightingharvesting',
#  'routine',
#  'upbadges',
#  'calorie',
#  'penalize',
#  'clubcard',
#  'hahaha',
#  'wiki',
#  'technology',
#  'haha',
#  '22k',
#  'disney',
#  '73018',
#  'fategrand',
#  'cw',
#  'omits',
#  'xl3',
#  'mimi',
#  'carrot',
#  'dotsopen',
#  'reap',
#  'helpfuli',
#  'unruly',
#  'ca',
#  'advertisement',
#  'heel',
#  'onbut',
#  'butafter',
#  'buttonin',
#  'graphing',
#  'obsessive',
#  'jealousy',
#  'defect',
#  'suffers',
#  'equipped',
#  'topuped',
#  'soothe',
#  'thenivijayfans',
#  'authentication',
#  'gooapp',
#  'supervisor',
#  'friend',
#  '2mb',
#  'kagillion',
#  'prm',
#  'carey',
#  'director',
#  'dug',
#  'seemed',
#  'sunset',
#  'make',
#  'nay',
#  'crush',
#  'americanized',
#  'fricken',
#  'hitwe',
#  'anticipates',
#  'annoys',
#  'yearand',
#  'sally',
#  'brightest',
#  'blinding',
#  '100mega',
#  'kindve',
#  'organizing',
#  'kitchen',
#  'italicized',
#  'enter',
#  'appam',
#  'carying',
#  'gracias',
#  'usercentric',
#  'load',
#  'cbssports',
#  'night',
#  'besoccer',
#  'surekeep',
#  'cockerel',
#  '13x13',
#  'joystick',
#  'vid',
#  'waitand',
#  'early',
#  'purchase',
#  'acounte',
#  'liam',
#  'demonstrated',
#  'collage',
#  '400m',
#  'adsi',
#  'glitched',
#  'twynsta',
#  'synching',
#  'completing',
#  'alil',
#  'mulch',
#  'hhmmss',
#  'laughably',
#  'pose',
#  'loosing',
#  'follow',
#  'uncluttered',
#  'liplock',
#  'ectsso',
#  'carl',
#  '340',
#  'blurry',
#  'gameforbullies',
#  'province',
#  'stlbs',
#  '4☆',
#  'seven',
#  'itstill',
#  'taxthey',
#  'inputted',
#  'choise',
#  'frustratingeverything',
#  'wimp',
#  '£50£60',
#  'innerupting',
#  'skill',
#  'updateam',
#  'june',
#  'gping',
#  'discussing',
#  'kita',
#  'earned',
#  'pregnancy',
#  'signature',
#  'one।',
#  'motorolas',
#  'tothe',
#  'arun',
#  'showingowner',
#  'chatter',
#  'entrainment',
#  'sniper',
#  'gadget',
#  'really❤❤',
#  'raiting',
#  '1996',
#  'cope',
#  'personality',
#  'wkd',
#  'sisspine',
#  'worried',
#  'gobank',
#  'computation',
#  'adjusted',
#  'theaterseating',
#  'opener',
#  'image',
#  'ditch',
#  'persists',
#  'nagging',
#  'rpg',
#  'pramote',
#  'figuratively',
#  'flush',
#  'gorving',
#  'he',
#  'avoided',
#  'wist',
#  'selects',
#  'juer',
#  'waa',
#  'mony',
#  'chant',
#  'balance',
#  'birthdatehow',
#  'millisecond',
#  'unskipable',
#  '13months',
#  'cumbersome',
#  '71618',
#  'textbook',
#  'recived',
#  'rovia',
#  'excercise',
#  'prediabetes',
#  'collar',
#  'pausing',
#  'mingle2',
#  '26',
#  'banorte',
#  'barrage',
#  'orbot',
#  'secretary',
#  'inexpensive',
#  'bravo',
#  'alloverthis',
#  'collector',
#  'storeshop',
#  '100yards',
#  'longerterm',
#  '67',
#  'wunderkind',
#  'loudly',
#  'slam',
#  'severs',
#  'universal',
#  'cat',
#  'playpurchase',
#  '23of',
#  'deletehide',
#  'againlol',
#  'problematic',
#  'crockpot',
#  'may2018',
#  'weaving',
#  '250',
#  'historically',
#  'confirming',
#  'rating',
#  'eatstreet',
#  'citibank',
#  'succulent',
#  'epocrate',
#  'skirt',
#  'irks',
#  'itdont',
#  'basset',
#  'architecture',
#  'junior',
#  '2011',
#  'liket',
#  'beleibed',
#  '3plus',
#  'thatany',
#  'memorized',
#  'document',
#  'watchface',
#  'emm',
#  'defective',
#  'taskeretc',
#  'rework',
#  'pointsgreat',
#  'ouye',
#  'narrated',
#  'errornetwork',
#  'imperative',
#  'ko',
#  'financials',
#  'appa',
#  'likedcommented',
#  'helpfulness',
#  'youkeep',
#  'motivate',
#  'diming',
#  'almighty',
#  'cvscaremark',
#  '30carbs',
#  'dab',
#  'cheatable',
#  'crore',
#  'loud',
#  'shack',
#  'ladyeasy',
#  'irritation',
#  'freesing',
#  'obligatory',
#  'bit',
#  'monththats',
#  'dvt',
#  'stake',
#  'scrap',
#  'collusion',
#  'rgem',
#  'std',
#  'nearest',
#  'pool',
#  'transferred',
#  'sayso',
#  'niv',
#  'pulip',
#  'sexuality',
#  'song',
#  'humour',
#  'predesigned',
#  'your',
#  'looked',
#  'dikha',
#  'hmm',
#  'stoo',
#  'texting',
#  'brilliantly',
#  'turtorial',
#  'citibanamex',
#  'terrible',
#  'deception',
#  'comprises',
#  'updatei',
#  'robbie',
#  'guns6',
#  'phase',
#  'pinterest',
#  'howeverthe',
#  'understating',
#  'linei',
#  'arizona',
#  'okay',
#  'safe',
#  'screenhow',
#  'dieting',
#  'v442',
#  'cologne',
#  'hasslefree',
#  'lifesaving',
#  'lululemon',
#  'thoose',
#  'concectet',
#  'pricy',
#  'goody',
#  'mound',
#  'impress',
#  'god',
#  'costco',
#  's9',
#  'compromised',
#  'openfetures',
#  'pokardo',
#  '2030',
#  'bugfix',
#  'personaly',
#  '♥️',
#  'atrocious',
#  'properlyspell',
#  '2499c',
#  'appropriate',
#  'thia',
#  'schnitzel',
#  'straw',
#  'bitpay',
#  '”',
#  'isolate',
#  'oloshi',
#  'direct',
#  'derogatory',
#  'usmuslims',
#  'ltrs',
#  'moral',
#  'hubby',
#  'annoyes',
#  'medal',
#  'losin',
#  'slowerthan',
#  'resource',
#  'badpigs',
#  'acquire',
#  'paybills',
#  'qhere',
#  '1min',
#  'dated',
#  'landline',
#  'profession',
#  'coherent',
#  'authorized',
#  'dialed',
#  'dex',
#  'themi',
#  'uplift',
#  'apostrophe',
#  'pinging',
#  '♥♥',
#  'vote',
#  'blogaway',
#  'updatesbeen',
#  'sleek',
#  'without',
#  'explain',
#  'gh',
#  '5⭐',
#  'blurred',
#  'account',
#  'shortcoming',
#  '885',
#  'integrity',
#  'bearing',
#  '♡♡',
#  'retain',
#  'devotion',
#  'scolling',
#  'lb',
#  'refinance',
#  'shoving',
#  'ib',
#  'generous',
#  'abundantly',
#  'shaking',
#  'graphicsfun',
#  'limiting',
#  'tie',
#  'ip',
#  'shared',
#  'trophy',
#  '2300',
#  'likewise',
#  'ofcourse',
#  'workef',
#  'gboard',
#  'some',
#  'poach',
#  'contrnents',
#  'jun',
#  'holder',
#  'applicationeverytime',
#  'romanian',
#  'determined',
#  'root',
#  'preconception',
#  'beside',
#  '1130',
#  'conner',
#  'hapify',
#  '22months',
#  'butcan',
#  'pick',
#  '426am',
#  'expedia',
#  'stretching',
#  'kdosid837ud8388388iziwixiiaiiwisosidixkskd',
#  '4g3g',
#  'groc',
#  'turned',
#  'carfax',
#  'tot',
#  'thumbing',
#  '622',
#  'protocol',
#  'watchthanks',
#  'goodsexercise',
#  'adjective',
#  'shett',
#  'discourage',
#  'johnwoelke',
#  'i＊ve',
#  'ashamed',
#  'deseve',
#  'description',
#  'dine',
#  'debating',
#  'wholesome',
#  'fixis',
#  'flightradar',
#  'appsjust',
#  'grabbing',
#  'squirrelly',
#  'absolute',
#  'cam',
#  'smartphone',
#  'fubared',
#  'genius',
#  'contract',
#  'supposed',
#  'inadvertently',
#  'mkin',
#  'median',
#  'savingsimpaired',
#  'cordial',
#  'isit',
#  'grown',
#  'pather',
#  'disliking',
#  'instagram',
#  'priv',
#  'mange',
#  'concordance',
#  'anita',
#  'facebookmessenger',
#  'rip',
#  'seedy',
#  'dissapointing',
#  'hypnotic',
#  'tripped',
#  'hindrance',
#  'bodybuilding',
#  's9no',
#  'fruitsbest',
#  'scoldcriticize',
#  'skillproblem',
#  'timed',
#  'bundled',
#  'rapper',
#  'strengthen',
#  'thankfull',
#  'dy',
#  'reconnecting',
#  'noo',
#  'rarley',
#  'emd',
#  'trongs',
#  'reay',
#  'tollataly',
#  'retaining',
#  'pending',
#  'reboots',
#  'updaterated',
#  '838',
#  '824',
#  'usda',
#  'reappearing',
#  'better',
#  'tsk3x',
#  'hooked',
#  'onr',
#  'swallow',
#  'bending',
#  'percent',
#  'dunkin',
#  'flirting',
#  'creditdebit',
#  'manager',
#  'convincing',
#  'logistics',
#  'applicationdevice',
#  '430a',
#  'neat',
#  'billy',
#  'lend',
#  'newspaperand',
#  'allwhy',
#  '52mb',
#  'march',
#  'prioritize',
#  'cure',
#  'vibratesilent',
#  'horrific',
#  'playrixnot',
#  'contactsbackup',
#  '3500m',
#  'weakest',
#  'flogging',
#  'segregate',
#  'kepper',
#  'estimator',
#  'overjoyed',
#  'refill',
#  'majority',
#  'numberlol',
#  'sleeker',
#  'wedding',
#  'aitype',
#  '51900',
#  'whoever',
#  '945',
#  'premarket',
#  'mmdd',
#  'gal',
#  'soundtrip',
#  'freelance',
#  'plural',
#  'eg',
#  'cancelled',
#  'fusion',
#  'organized',
#  'aaddss',
#  'captivative',
#  'sun',
#  'possi',
#  'therent',
#  'journaling',
#  'committed',
#  'networkradio',
#  'sht',
#  'ai',
#  'declin',
#  'loss',
#  'arnold',
#  'stripping',
#  'upwards',
#  'waterfront',
#  'tofrom',
#  'saddened',
#  'purchasing',
#  'niceyou',
#  'popup',
#  'whereby',
#  'note8',
#  'contrail',
#  'mpw',
#  'input',
#  '1954',
#  'creat',
#  '1weeks',
#  'ahmm',
#  'eleh',
#  'agreethere',
#  'superficial',
#  'moodplease',
#  'disturbed',
#  'yourselves',
#  'nanually',
#  'tittle',
#  'loginit',
#  'wan',
#  'zeti',
#  'molt',
#  'paedophile',
#  'backspace',
#  'upwith',
#  'stating',
#  'district',
#  'y7',
#  'leukemia',
#  'climate',
#  'professionallooking',
#  'costume',
#  'imei',
#  'ketogenic',
#  'programmer',
#  'sweden',
#  'bmo',
#  'crosby',
#  'groupchat',
#  'attracted',
#  'breathe',
#  'guy',
#  'petty',
#  'oneplus',
#  'opn',
#  'permission',
#  'goodbye',
#  'scan',
#  'levelup',
#  'providerplease',
#  'pressed',
#  'summertime',
#  'squinting',
#  'megaload',
#  '2147',
#  'hyorunning',
#  'effectivelyif',
#  'mclaren',
#  'stuckpixel',
#  'alaska',
#  'motivating',
#  '80m',
#  'breach',
#  'moemtn',
#  'farthest',
#  'unprocesseable',
#  'blocky',
#  'efficiently',
#  'nickjr',
#  'narration',
#  'hiss',
#  'usedthis',
#  'vpar',
#  'freeform',
#  'ley',
#  'silence',
#  'using',
#  'musharaf',
#  'crate',
#  'throughout',
#  'screwing',
#  'clouding',
#  'applied',
#  '3g',
#  'accomplishment',
#  'ampm',
#  'mykle',
#  'weezer',
#  'reviewhere',
#  'torment',
#  'lack',
#  'uhhthe',
#  'alto',
#  'golem',
#  'twothree',
#  'madrid',
#  'progession',
#  'suspicion',
#  'yuk',
#  'sitegood',
#  'spying',
#  'mert',
#  'todo',
#  'andcan',
#  'anywhere',
#  'noodlecake',
#  'appilication',
#  'crock',
#  'contribution',
#  'insulting',
#  'are',
#  'roktavor',
#  'midfielders',
#  'summed',
#  'starter',
#  'extracted',
#  'customizations',
#  'townhouse',
#  'referee',
#  'surgeon',
#  'hypocritical',
#  'observe',
#  'niether',
#  'entice',
#  'tip',
#  'attending',
#  'disclosure',
#  '1500',
#  'fiancee',
#  'uplifted',
#  '652mbs',
#  'microsoft',
#  'useres',
#  'baby',
#  'riddance',
#  'evernote',
#  'aranges',
#  'example',
#  'comment',
#  '10262017',
#  'diamond',
#  'repayment',
#  'thisi',
#  'handling',
#  'fanfkin',
#  'felix',
#  'captivating',
#  'keepimg',
#  'derivative',
#  'unistalled',
#  'angle',
#  'startegy',
#  'spectacularly',
#  'blasted',
#  'emailed',
#  'forward',
#  'any',
#  'salsa',
#  'britches',
#  'township',
#  'shoters',
#  'f3when',
#  'memorable',
#  'sunrise',
#  'textra',
#  'renovatedupgradedpainted',
#  'dying',
#  'wised',
#  'pet',
#  'diagonally',
#  'craze',
#  'paris',
#  'paddock',
#  'validated',
#  '40mg5mg',
#  'digger',
#  'behave',
#  'lag',
#  'olden',
#  'incase',
#  'keying',
#  'hacked',
#  'joking',
#  'besf',
#  'next',
#  'infomercial',
#  'welljust',
#  'incontext',
#  'stroking',
#  'logcat',
#  '★★◆',
#  'lightvery',
#  'systemui',
#  'oak',
#  'stunningly',
#  '2years',
#  '3d4',
#  'bt',
#  'pv',
#  'hay',
#  'cough',
#  'readable',
#  'started',
#  'inspired',
#  'looping',
#  'expenditure',
#  'downloaded',
#  'upsi',
#  '96',
#  'astonishing',
#  'pharmacy',
#  'orshe',
#  'uncomfortable',
#  '30yrslove',
#  'shattered',
#  '8year',
#  'measly',
#  'temple',
#  'stuf',
#  'opened',
#  '50200',
#  'somethings',
#  'autocorrect',
#  'bulletednumbered',
#  'writing',
#  'themall',
#  'subtitutions',
#  'acrossthe',
#  'kafi',
#  'juz',
#  'boa',
#  'getter',
#  'produced',
#  'oldest',
#  'treasure',
#  'yeahh',
#  'automatically',
#  'barral',
#  'impossibletoseeinsunlight',
#  '27',
#  'chelsea',
#  'razakjoefaimonksiliconniesonypeggykiwwiyat',
#  'solo',
#  'withut',
#  'dude',
#  'rage',
#  'excisting',
#  'hat',
#  'greatly',
#  'chatting',
#  'veges',
#  '185',
#  'informstion',
#  'darhyna',
#  'profound',
#  'availability',
#  'oops',
#  'unabe',
#  'too',
#  'လေတွေ',
#  'outer',
#  '1428',
#  'diy',
#  'damage',
#  'fetish',
#  'gracefully',
#  'installedin',
#  'serviceable',
#  '589',
#  'recmond',
#  'parrot',
#  'grooming',
#  'btinternet',
#  'installd',
#  'fup',
#  'dec',
#  'wx',
#  'aug',
#  'wildlife',
#  'hamcam',
#  'recd',
#  'pices',
#  'irfan',
#  'protection',
#  'mouse',
#  '30seconds',
#  'lynbrook',
#  'regionalise',
#  'frozen',
#  'swore',
#  'niceit',
#  'wroe',
#  'quest',
#  'sooner',
#  'password',
#  'twist',
#  'icon',
#  'ungrateful',
#  'wht',
#  'unheard',
#  'taxi',
#  'palm',
#  'berry',
#  'stephen',
#  'ditching',
#  '12718',
#  'sharpness',
#  'vigan',
#  'conscience',
#  'snyghjngeither',
#  'autistic',
#  '2£',
#  'honour',
#  'crossing',
#  'aligned',
#  'pragrams',
#  'boredom',
#  'intermittently',
#  'fixitplease',
#  'separation',
#  'flint',
#  'few',
#  'anitfa',
#  '4when',
#  'meeting',
#  'this❤',
#  'rewarding',
#  'uncle',
#  'fantasyfootball',
#  'kenya',
#  'aggregated',
#  'helos',
#  'mediocre',
#  '44',
#  'kpop',
#  'rigged',
#  '57',
#  '200miles',
#  'starving',
#  'blank',
#  'theneven',
#  'crashea',
#  'validity',
#  'bounce',
#  'sent',
#  'bureaucratic',
#  'ridiculously',
#  '41ebe',
#  'connectionbt',
#  'expression',
#  'chore',
#  'bunny',
#  'tax',
#  'moree',
#  'thatbut',
#  'returants',
#  'uops',
#  'inclined',
#  'yjr',
#  ...}

# %% [markdown]
# Then for each data point (tokens with the pos/neg tag), we will build a dictionary that says whether it has particular features/ words from the vocabulary.

# %%
def features_with_labels(row):
    return ({i:(i in row["Review"]) for i in vocabulary}, row["Sentiment"])

features = x_train.progress_apply(features_with_labels, axis=1)
# Out:
# 100%|██████████| 7485/7485 [15:23<00:00,  8.11it/s]

# %%
classifier = NaiveBayesClassifier.train(features)

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                    great = True           Positi : Neutra =     51.5 : 1.0
#                     easy = True           Positi : Neutra =     48.2 : 1.0
#                      lov = True           Positi : Neutra =     33.8 : 1.0
#                     love = True           Positi : Neutra =     33.1 : 1.0
#                 horrible = True           Negati : Positi =     26.9 : 1.0
#                     nice = True           Positi : Neutra =     26.5 : 1.0
#                 provider = True           Neutra : Positi =     25.8 : 1.0
#                    relax = True           Positi : Negati =     21.2 : 1.0
#                      hop = True           Positi : Neutra =     21.1 : 1.0
#                      lem = True           Negati : Neutra =     20.0 : 1.0

# %%
def features(row):
    return {i:(i in row["Review"]) for i in vocabulary}

test_features = x_test.progress_apply(features,axis=1)
