# %% [markdown]
# # Preliminary Naive Bayes Model for Sentiment Polarity

# %% [markdown]
# Import necessary dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
tqdm.pandas()

# For Tokenizing
import re
import string
import itertools
from spellchecker import SpellChecker
from contractions import contractions_dict

from nltk import download, word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer

# For Text Classification
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment import SentimentAnalyzer
from nltk.corpus import subjectivity
from nltk.classify import NaiveBayesClassifier

# %% [markdown]
# Download Necessary Corpus for tokenizer, and sentiment analyzers to work.

# %%
download('punkt')
download('stopwords')
download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /home/lyqht/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/lyqht/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/lyqht/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ## The Dataset

# %% [markdown]
# Import the dataset and rename some columns

# %%
df = pd.read_csv("../data/googleplaystore_user_reviews.csv")
df.rename(columns = {'Translated_Review':'Review'}, inplace=True)
df.sample(4)
# Out:
#                                   App  \
# 1192                 7 Minute Workout
# 55073                Google Assistant
# 33793         Diabetes & Diet Tracker
# 57978  Gyft - Mobile Gift Card Wallet
#
#                                                   Review Sentiment  \
# 1192                                                 NaN       NaN
# 55073                                                NaN       NaN
# 33793                               Fantastic! Easy use!  Positive
# 57978  Annoying need know exactly much add gift card....  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 1192                  NaN                     NaN
# 55073                 NaN                     NaN
# 33793            0.520833                0.866667
# 57978           -0.300000                0.550000

# %% [markdown]
# ## Terminology
# Source of definitions: Bing Liu. Sentiment Analysis and Opinion Mining, Morgan & Claypool Publishers, May 2012
# - Sentiment Polarity: Can be split into rational or emotional sentiment. Hence resulting in the common design of 5 sentiment ratings.
#     - emotional negative (-2)
#     - rational negative (-1)
#     - neutral (0): In practice, neutral often means no opinion or sentiment expressed.
#     - rational positive (+1)
#     - emotional positive (+2)
# - Sentiment Subjectivity: Subjective sentences expresses some personal feelings, views, or beliefs. They may not express any sentiment.

# %% [markdown]
# We see that the original dataset also has labels of the sentiment level, polarity and subjectivity by the original author.
# We will build our own model then compare the values to the values in the original dataset for comparison.

# %% [markdown]
# Getting the reviews

# %%
raw_reviews = df["Review"].copy()
raw_reviews.sample(5)
# Out:
# 61442    After update, game literally worst play, PVP i...
# 54599    Golfnow brilliant. Great deals easy use. 1 pro...
# 58429    Nice sharp vibrant photos. Has lot nice edit f...
# 55762    I want report problem Google Earth: street vie...
# 3039                      You manage permission ask nougat
# Name: Review, dtype: object

# %% [markdown]
# # Text Mining

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# We will drop NA types in the reviews data, since they do not contain any text. We will also remove duplicates. They probably got into the dataset because of imperfect data scraping.

# %%
reviews = raw_reviews.dropna(axis=0).drop_duplicates()
print("Old data frame length:", len(raw_reviews), "\nNew data frame length:",  
       len(reviews), "\nNumber of rows with at least 1 NA value: ", 
       (len(raw_reviews)-len(reviews)))
# Out:
# Old data frame length: 64295
# New data frame length: 27994
# Number of rows with at least 1 NA value:  36301

# %% [markdown]
# These are the preprocessing steps that we will be doing for every review.
# 1. Converting text to lowercase
# 2. Remove html tags
# 3. Expand Contractions
#     - Dictionary source from : https://github.com/pemagrg1/Text-Pre-Processing-in-Python/blob/master/individual_python_files/contractions.py
# 4. Remove punctuation
# 5. Using NLKT's `PunktSentenceTokenizer` to create tokens
# 6. Word Normalization for Tokens
#     - Correcting mispelled words
#     - Stop word removal
#     - Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
stopword = set(stopwords.words('english'))
spell = SpellChecker()

# Regex Patterns
html_pattern = re.compile('<[^<]+?>')
lengthening_pattern = re.compile(r"(.)\1{2,}")
contractions_pattern = re.compile('({})'.format('|'.join(contractions_dict.keys())),
                                      flags=re.IGNORECASE | re.DOTALL)

def remove_html_tags(s):
    global html_pattern
    return html_pattern.sub('', s)
    
def remove_punctuation(s):
    return s.translate(str.maketrans('', '', string.punctuation))    

def expand_contractions(text):
    global contractions_pattern
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contractions_dict.get(match) \
            if contractions_dict.get(match) \
            else contractions_dict.get(match.lower())
        expanded_contraction = expanded_contraction
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

def reduce_lengthening(s):
    global lengthening_pattern
    return lengthening_pattern.sub(r"\1\1", s)

def lemmatize(w):
    global lemmatizer
    return lemmatizer.lemmatize(w)

def normalize(s):
    global spell
    tokens = word_tokenize(s)
    tokens = [lemmatize(word) for word in tokens]
    return tokens


def preprocess(s):
    s = s.lower()
    s = remove_html_tags(s)
    s = expand_contractions(s)
    s = remove_punctuation(s)
    s = reduce_lengthening(s)
    words = normalize(s)
    
    return words

# %% [markdown]
# Applying preprocessing to all the reviews

# %%
tokens = reviews.apply(preprocess)
processed_df = pd.DataFrame(reviews)
processed_df["Tokens"] = tokens
processed_df.sample(5)
# Out:
#                                                   Review  \
# 2587   The ads much flashing jumping around cannot ev...
# 42718  When comes healthy habits, well habits, I'm wo...
# 31074                             Tanx For idea, lovely.
# 63398  Just yesterday I booked flight find skyscanner...
# 9685   Nice graphics/animation purpose game sell virt...
#
#                                                   Tokens
# 2587   [the, ad, much, flashing, jumping, around, can...
# 42718  [when, come, healthy, habit, well, habit, wors...
# 31074                          [tanx, for, idea, lovely]
# 63398  [just, yesterday, i, booked, flight, find, sky...
# 9685   [nice, graphicsanimation, purpose, game, sell,...

# %% [markdown]
# Saving this data for reuse

# %%
processed_df.to_csv("../data/tokenized.csv")

# %% [markdown]
# Visualizing the most common tokens and saving the plot

# %%
fig = plt.figure(figsize = (10,4))
plt.gcf().subplots_adjust(bottom=0.15)

word_counts = list(itertools.chain(*tokens))
freq_dist = FreqDist(word_counts)
freq_dist.plot(30, cumulative=False)

plt.show()
fig.savefig('images/freqDist.png', bbox_inches = "tight")

# %% [markdown]
# Some steps that we did not include for preprocessing that could affect our model:
# - Removing numbers: sometimes in reviews we see that users explain their rationale of giving a specific number of star rating, so we did not want to remove them.
# - Removing chinese reviews and apps: We assumed that China does not have access to Google Playstore, so there will be lesser chinese reviews and apps made in Chinese, but this is certainly not true. However, filtering them out is a hassle atm so we did not do this step.
# - Spell Checking every token: We tried this, but it causes the computation to be taking too long! So we ignore it for now...

# %% [markdown]
# # Modelling

# %% [markdown]
# We will use `VADER SentimentIntensityAnalyzer` for calculating polarity scores for each review. The scoring is computed as following from https://github.com/cjhutto/vaderSentiment:
#
# - The `compound` score is computed by summing the valence scores of each word in the lexicon, adjusted according to the rules, and then normalized to be between -1 (most extreme negative) and +1 (most extreme positive). This is the most useful metric if you want a single unidimensional measure of sentiment for a given sentence. Calling it a 'normalized, weighted composite score' is accurate.
#     - positive sentiment: compound score >= 0.05
#     - neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
#     - negative sentiment: compound score <= -0.05
#
# The `pos`, `neu`, and `neg` scores are ratios for proportions of text that fall in each category (so these should all add up to be 1... or close to it with float operation). These are the most useful metrics if you want multidimensional measures of sentiment for a given sentence.

# %%
analyzer = SentimentIntensityAnalyzer()
def sentiment_polarity(s):
    global analyzer
    polarity_scores = analyzer.polarity_scores(s)
    compound_score = polarity_scores["compound"]
    if compound_score >= 0.5:
        label = "Positive"
    elif compound_score > -0.05 and compound_score < 0.05:
        label = "Neutral"
    else:
        label = "Negative"
    return label, polarity_scores["neu"], polarity_scores["pos"], polarity_scores["neg"], compound_score

# %%
df = processed_df
df["Sentiment"], df["Neutral Proportion"], df["Positive Proportion"], df["Negative Proportion"], df["Compound Score"] =  zip(*df["Review"].apply(sentiment_polarity))
df.sample(3)
# Out:
#                                                   Review  \
# 41750  Ads nauseating, I dont care games force ads yo...
# 4281   It's always wanted pdf program. Adobe got righ...
# 7359   I played angry birds since first started. I've...
#
#                                                   Tokens Sentiment  \
# 41750  [ad, nauseating, i, dont, care, game, force, a...  Negative
# 4281   [it, is, always, wanted, pdf, program, adobe, ...   Neutral
# 7359   [i, played, angry, bird, since, first, started...  Negative
#
#        Neutral Proportion  Positive Proportion  Negative Proportion  \
# 41750               0.644                0.187                0.169
# 4281                1.000                0.000                0.000
# 7359                0.577                0.191                0.232
#
#        Compound Score
# 41750          0.0701
# 4281           0.0000
# 7359           0.0516

# %%
df.to_csv("../data/reviews_naive_polarity.csv")

# %% [markdown]
# Now we will classify the reviews based on subjectivity using a `NaiveBayesClassifier`. First, we split the data for testing and training.

# %%
test_size = int(0.2*len(reviews))
x_train = df[:test_size]
x_test = df[test_size:]

# %% [markdown]
# Next, we build a vocabulary consisting of all the words that the training set of reviews have. From the output, you can see that there is still much to be improved upon for the tokens that were obtained despite the preprocessing.

# %%
vocabulary = set(word_counts)
print("Number of words in vocabulary: {}".format(len(vocabulary)))
vocabulary
# Out:
# Number of words in vocabulary: 22322
# {'afterwards',
#  'retailer',
#  'colornotes',
#  'googlez',
#  'beach',
#  'engineeringmech',
#  'turnstile',
#  'instal',
#  'colourscategories',
#  'cloth',
#  'thing',
#  '68',
#  'preciate',
#  'kid',
#  'calmingi',
#  'exalent',
#  'believing',
#  'brick',
#  'almighty',
#  '62218',
#  'deposit',
#  'neverending',
#  '591',
#  'rcv',
#  'compresszip',
#  'number',
#  'cooler',
#  'freemium',
#  'global',
#  'buzzfeed',
#  'dataspy',
#  'restabiliseh',
#  'clear',
#  'climactic',
#  'inexplicably',
#  'authorised',
#  'chu',
#  'reporter',
#  'hercalendar',
#  'itnothing',
#  'ure',
#  '64gig',
#  'alive',
#  'overdrafted',
#  'idiologic',
#  'retrieve',
#  'greed',
#  'babbels',
#  'goli',
#  'thins',
#  'itinerary',
#  'elixiir',
#  'pulling',
#  'youlet',
#  'replaced',
#  'randomlygenerated',
#  'heavy',
#  'send',
#  'worried',
#  'poisonous',
#  'satrs',
#  'longer',
#  'packge',
#  '…130tu',
#  'fubared',
#  'shove',
#  'reworking',
#  'vidmet',
#  'asap',
#  'ub',
#  'cacts',
#  'owe',
#  'crossy',
#  'travel',
#  'anywhere',
#  'newsfeedespecially',
#  'apptwo',
#  'modesfood',
#  'greek',
#  'interpreting',
#  'bangle',
#  'eventhought',
#  'mediocre',
#  'preferable',
#  'taker',
#  'infuriating',
#  'nicewhat',
#  'playing',
#  'mable',
#  'toany',
#  'notebook',
#  'subdirectory',
#  'fl',
#  '85gold',
#  'unquestionably',
#  'appcayce',
#  'curated',
#  'wrongwhile',
#  'flying',
#  'prop',
#  'specialand',
#  'goodthe',
#  'pice',
#  'footstep',
#  '23rd',
#  'formatting',
#  'desperation',
#  '★★◆',
#  'peng',
#  'hilus',
#  '158',
#  'enjoyful',
#  'fined',
#  'responsiveness',
#  'lolipop',
#  'inserted',
#  'hoesntly',
#  'procrastination',
#  'batch',
#  'monkey',
#  'necessarily',
#  'exploded',
#  'missing',
#  'counterpart',
#  'move',
#  'obscenity',
#  'tah',
#  'diveroll',
#  'asks',
#  'reprocussions',
#  'utter',
#  'narrative',
#  'ir',
#  'reservoir',
#  'roaming',
#  'empowered',
#  'profession',
#  'momentum',
#  'engineplease',
#  'about',
#  'flour',
#  'council',
#  'hairu',
#  'amused',
#  'violence',
#  'stopedotherwise',
#  'presently',
#  'polly',
#  'etrade',
#  'fanbase',
#  'yogi',
#  'pinball',
#  '40fat',
#  'dosti',
#  'dr',
#  '626s',
#  'footage',
#  'sgt',
#  'stare',
#  'deteriorate',
#  'prprlyapps',
#  'emojies',
#  'costi',
#  'displayed',
#  'sum',
#  'til',
#  'door',
#  'measured',
#  'everydaysome',
#  'tetri',
#  'hiccupsas',
#  'noëls',
#  'accomplishment',
#  'rotten',
#  'miller',
#  'menuchrome',
#  'atlnap',
#  'aca',
#  'ning',
#  'sub',
#  '3800',
#  'fi',
#  '215',
#  'om',
#  'karo',
#  'cardaccount',
#  'dissuade',
#  'shut',
#  'x2',
#  'panicked',
#  '154',
#  'nonsensical',
#  'redo',
#  'israeli',
#  'sucksdoesnt',
#  'lm',
#  'niche',
#  'disided',
#  'beta',
#  'turning',
#  'im',
#  'bhogale',
#  'pad',
#  'willow',
#  'pcx',
#  'specializing',
#  'format',
#  'earlyand',
#  'yoga',
#  'ketogenic',
#  'dishing',
#  'ideaapp',
#  'chantes',
#  'w',
#  'maximum',
#  'faithful',
#  'relive',
#  'usaebl',
#  'csv',
#  'inspiringly',
#  'yourself',
#  'finger',
#  'redemption',
#  'thang131',
#  'promise',
#  'secondoldest',
#  'thehealth',
#  'basethe',
#  'preorders',
#  'placing',
#  'intentionally',
#  'don',
#  'unrelenting',
#  'overdrive',
#  'law',
#  'beneath',
#  'remain',
#  'manipulative',
#  'openafter',
#  'ojalá',
#  'crossover',
#  'everythingive',
#  'mahoto',
#  'june',
#  'kannada',
#  'dnt',
#  'aug18',
#  'supportmany',
#  'peep',
#  'reached',
#  '5gb',
#  'kinney',
#  'lr',
#  'began',
#  'med',
#  'summons',
#  'reappear',
#  'socalled',
#  'configures',
#  'republic',
#  'thingsearch',
#  'script',
#  'monthsi',
#  '300',
#  'hour',
#  'ethernet',
#  'wingsuit',
#  'breakdown',
#  'puttv',
#  'perrdy',
#  'kjnd',
#  'nervous',
#  'healthelife',
#  'pr',
#  'audio',
#  'same',
#  'textra',
#  'oohh',
#  'practised',
#  'rock',
#  'certificate',
#  'phonebased',
#  'machinery',
#  'workstation',
#  'retire',
#  'mp',
#  '622',
#  'tear',
#  '…but',
#  'vivid',
#  'installation',
#  'exceeded',
#  'zoe',
#  'explosion',
#  'dude',
#  'appealed',
#  'fluctuating',
#  'offense',
#  'venicegreat',
#  'halifax',
#  'deviceit',
#  'acces',
#  'sensibilty',
#  'jumped',
#  '22months',
#  'recolor',
#  'fixitplease',
#  'contect',
#  'wereever',
#  'krogers',
#  '25th',
#  'helpfulthank',
#  'interface',
#  'dominican',
#  'theb',
#  'itand',
#  'false',
#  'disturbs',
#  'bingo',
#  'fm',
#  'raging',
#  'bran',
#  'enabler',
#  'definitley',
#  'lottle',
#  '124800',
#  'nawa',
#  'broadband',
#  'reactivite',
#  'rdma',
#  'unliking',
#  'portrait',
#  'muchplaying',
#  'debate',
#  'daisy',
#  'disliking',
#  'linger',
#  'sorted',
#  'dog',
#  'sickness',
#  'darkheart',
#  'windfall',
#  'sprinkle',
#  'newbs',
#  '1pizza',
#  'clocked',
#  'thread',
#  'quaterly',
#  'metropolitan',
#  'logo',
#  'ati',
#  'enougheven',
#  'yeahh',
#  'individual',
#  'biolife',
#  'vegeta',
#  'postpone',
#  'gphoto',
#  'triangle',
#  '5vs5',
#  'problemsvery',
#  'streamed',
#  'compatable',
#  '4547a',
#  'turtle',
#  'kotyadhipati',
#  'removal',
#  'download',
#  'reliance',
#  'hella',
#  'hustle',
#  'assign',
#  'champion',
#  'reimburse',
#  'pervert',
#  'appscough',
#  '2311',
#  'sharp',
#  'changelogs',
#  'avoids',
#  'dinar',
#  'callsfeeding',
#  'getup',
#  'tedious',
#  'connecting',
#  'lymph',
#  'wap',
#  'listscalendars',
#  'nova',
#  'worm',
#  'circumvented',
#  'so',
#  'collide',
#  'grandparent',
#  'fluf',
#  'recently',
#  'firat',
#  'crist',
#  'quik',
#  'srk',
#  'heel',
#  'poo',
#  'devotion',
#  'coranary',
#  'recreate',
#  'kist',
#  'fuelmaybe',
#  'gadget',
#  'yeouido',
#  'bet',
#  '1minabout',
#  'thoughtout',
#  'capacity',
#  'lyfi',
#  'cafe',
#  'resident',
#  'tmobile',
#  'expansion',
#  'unaware',
#  'linkage',
#  'invited',
#  '1pcs',
#  'risky',
#  'pricey',
#  'note8',
#  'annoyingit',
#  'colorful',
#  'isdoes',
#  'repairing',
#  'bullsht',
#  '10mb',
#  '¡gracias',
#  'wifimobile',
#  'vessel',
#  'utilized',
#  'loveattraction',
#  'scribbling',
#  'mercato',
#  'simpele',
#  'swath',
#  'prove',
#  'mebecause',
#  '9973',
#  'uncloseable',
#  'permission',
#  'holiday',
#  '5but',
#  'itenary',
#  'filtered',
#  'agoda',
#  'coded',
#  'encrypted',
#  'inoreader',
#  'vaguely',
#  'mishra',
#  'compatibility',
#  'stocked',
#  'aver',
#  'notification',
#  'gently',
#  'someone',
#  'freak',
#  'serf',
#  'pleasing',
#  'dueling',
#  'encryption',
#  'weaset',
#  'diploma',
#  '136',
#  'irs',
#  'smashing',
#  'qalaxy',
#  'crunch',
#  'asinine',
#  'there',
#  'wish',
#  'memory',
#  'trialed',
#  'transpirency',
#  'tractos',
#  'special',
#  'rumor',
#  'arranges',
#  'progresshours',
#  'unfixed',
#  'hacking',
#  'akb',
#  'kaspersky',
#  'terrible',
#  'dimmed',
#  'mar',
#  'pulque',
#  'teleservices',
#  'incompatible',
#  'moana',
#  'begging',
#  'j016',
#  'painstakingly',
#  'outgoing',
#  'exigent',
#  'hassel',
#  'fixing',
#  'highlighting',
#  'allah',
#  '116',
#  'monetizing',
#  'fab',
#  'esanatomy',
#  'wo4k',
#  'oleenbi',
#  '1x',
#  'couponing',
#  'blocked',
#  'fetching',
#  'losse',
#  'z2',
#  'condense',
#  'highlydetailed',
#  'quit',
#  'priceless',
#  'beeper',
#  'vapor',
#  'downloadable',
#  'stressanxietyand',
#  'disingenuous',
#  'internet',
#  'a729bt',
#  'cookbook',
#  '196',
#  'cycle',
#  'kik',
#  'randomfun',
#  'updatemay',
#  'gameis',
#  'inplease',
#  'involuntarily',
#  'stat',
#  '1997',
#  'asian',
#  'reyes',
#  'immunity',
#  'matchmaking',
#  'textsnotes',
#  '139',
#  'technlogically',
#  'capitalizing',
#  'nowevery',
#  'otberwise',
#  'impressively',
#  'lemon',
#  'linealso',
#  'interupt',
#  'splicing',
#  '1624',
#  'laserdisc',
#  'ht',
#  'whit',
#  '399',
#  'manchester',
#  'newstand',
#  'ugly',
#  'moi',
#  'justice',
#  'gov',
#  'annoying',
#  'message',
#  'williams',
#  'crapp',
#  'nothing',
#  'cow',
#  'detectedclick',
#  'pedowood',
#  'baptist',
#  'cecil',
#  'gt¢√lt',
#  'persistent',
#  'studioetc',
#  'glancing',
#  'biking',
#  'cacashin',
#  'answeted',
#  'mindnumbingly',
#  'reliable',
#  'sudy',
#  'evrything',
#  'alwayson',
#  'english♡♡',
#  'undermined',
#  'iz',
#  'friendswhen',
#  'lucky',
#  'appever',
#  'prep',
#  'rented',
#  'estonia',
#  'journalisrtic',
#  'patch',
#  'shower',
#  'typs',
#  'fishy',
#  'by',
#  'day',
#  'blatantly',
#  'leagoo',
#  'presentation',
#  'predictive',
#  'how',
#  'pit',
#  'duolingo',
#  'kidsfamilys',
#  'godsend',
#  'secondary',
#  'connectionit',
#  'dynamic',
#  'systematically',
#  'headset',
#  'voila',
#  'allotment',
#  'plow',
#  'goodby',
#  'pictureor',
#  'g6',
#  'flustered',
#  'workout',
#  'nostalgic',
#  'bilg',
#  'i＊m',
#  'infatuated',
#  'takeover',
#  'desirable',
#  'grow',
#  'scammerscatfishers',
#  'tablett',
#  'littie',
#  'admirer',
#  'detail',
#  'custom',
#  'nmm',
#  'mcdonalds',
#  'enregistrate',
#  'xp',
#  'tanner',
#  'implied',
#  'youplease',
#  'perfectyet',
#  'dribble',
#  'screw',
#  'ibotta',
#  'jiggle',
#  'anoucements',
#  'waitin',
#  'sonetime',
#  'sum1',
#  'j5',
#  'delivers',
#  'pesky',
#  'naff',
#  'stretagy',
#  'monfri',
#  'sayits',
#  'relaxing',
#  'faith',
#  'agend',
#  'inspired',
#  'xml',
#  '723',
#  'sead',
#  'soul',
#  'onetwo',
#  'lifesaver',
#  'higher',
#  'deactivethankfully',
#  'nrwest',
#  'disconnecting',
#  'an',
#  'skyscanner',
#  'underlined',
#  'goggles',
#  'partner☺☺',
#  'isshame',
#  'demonstrated',
#  'acrobatcc',
#  'haveing',
#  'marina',
#  'nicely',
#  'misfit',
#  'okok',
#  '搵楼租楼',
#  'magooshs',
#  'memorize',
#  'costof',
#  'typical',
#  'sister',
#  'collector',
#  'adsvideos',
#  'patiently',
#  'ariel',
#  '50bars',
#  'extraterrestrial',
#  'u❤',
#  'arose',
#  'giadas',
#  'preform',
#  'prohibited',
#  'hostage',
#  'latefood',
#  'granting',
#  'truely',
#  'stoked',
#  'phone',
#  'jetblue',
#  '10xno',
#  'gmails',
#  'sacrificed',
#  'coil',
#  'addictive',
#  'hairdo',
#  'repetation',
#  'appuser',
#  'xoxo',
#  'unfreeze',
#  'plzzn',
#  'tailored',
#  'themeappcompat',
#  'mkad',
#  'clunkiest',
#  'restaurant',
#  'pointless',
#  'doughnut',
#  'axis',
#  'challengewise',
#  'loginconnect',
#  'crono',
#  'measurment',
#  'zenfone',
#  'fowled',
#  'feb',
#  'entertained',
#  'comic',
#  'charm',
#  'seattle',
#  'minimal',
#  'kittybevry',
#  'trojan',
#  'additional',
#  'jester',
#  'expose',
#  'prog',
#  'adsbreaks',
#  'goodjust',
#  'one',
#  'stomach',
#  'height',
#  'embarrassment',
#  'unfocussedetc',
#  'l0ve',
#  'checkpoint',
#  'power',
#  'resent',
#  '612',
#  'eleh',
#  'convention',
#  'carwyn',
#  'wifi',
#  'hng3p',
#  'disgusting',
#  'parsing',
#  'obliterate',
#  'forcefully',
#  'bookpdf',
#  'gamemaze',
#  'forge',
#  'banki',
#  'mattress',
#  'buttonswidgets',
#  'clan',
#  'adsand',
#  'solw',
#  'howsimple',
#  'νєяу',
#  'calltextcopy',
#  'effectivei',
#  'impartial',
#  'neari',
#  'issuesi',
#  'nonnumber',
#  'ungrateful',
#  'panther',
#  'sparkling',
#  'mp4',
#  'goalsign',
#  'avisonuevavesiontitulounplayable',
#  'surfer',
#  'osteoarthritis',
#  'spoke',
#  'gear',
#  'a9',
#  'mp5',
#  'organized',
#  'layup',
#  'aggressive',
#  'goalbut',
#  'sl',
#  'sounded',
#  '485',
#  'sweat',
#  'density',
#  'ifyukifyuk',
#  'barebones',
#  'footballer',
#  'hindi',
#  'progressive',
#  '20x',
#  'administrator',
#  'comfortably',
#  'para',
#  'supply',
#  'socialize',
#  'credit',
#  'enforced',
#  'reserving',
#  'dudeping',
#  'playpurchase',
#  'hype',
#  'cartridge',
#  'gif',
#  'lethal',
#  'leats',
#  'kept',
#  'welladapted',
#  'grenade',
#  'poly',
#  '365',
#  'fan',
#  'riddance',
#  'algorythems',
#  'bangett',
#  'fs18',
#  'guy',
#  'continuing',
#  'reallyhave',
#  'payouts',
#  'badd',
#  'staf',
#  'loy',
#  'occurring',
#  'querries',
#  'groupchats',
#  'disruption',
#  'calculated',
#  'uselove',
#  'asphalt',
#  'provides',
#  'men',
#  'goddamn',
#  'recorded',
#  'sung',
#  'valuesmacros',
#  'wrongi',
#  'lighting',
#  'recognizing',
#  'surviving',
#  'oaf',
#  'programed',
#  'iself',
#  'erased',
#  'urgently',
#  'tou',
#  'report',
#  'archer',
#  'attract',
#  'diluted',
#  'instaban',
#  'pixle',
#  '600',
#  'dkits',
#  'welcoming',
#  'constitution',
#  'hwas',
#  'spanish',
#  'accoladesi',
#  '2page',
#  'epitome',
#  'rust',
#  'death',
#  'go',
#  'flowing',
#  'reference',
#  'harvest',
#  'airasia',
#  'businessessociety',
#  'aug2018',
#  'payu',
#  'handsdown',
#  'resoluted',
#  'underpowered',
#  'litiature',
#  'ageing',
#  'navigation',
#  'usefor',
#  'megan356',
#  'perennially',
#  'administration',
#  'mortal',
#  'good',
#  'forceclose',
#  'nonstylus',
#  'forty',
#  'middle',
#  'exterior',
#  '400',
#  'lonely',
#  'nonstop',
#  'crexitdebit',
#  'kill',
#  'usefulcan',
#  'pesima',
#  'trail',
#  'adictive',
#  'alignment',
#  'slows',
#  'replayed',
#  'dtlocal',
#  'automative',
#  'disrupting',
#  'skillproblem',
#  'sooneri',
#  'mi5',
#  'litjust',
#  'discovery',
#  'grear',
#  'crib',
#  'carb',
#  'algorythm',
#  'alltime',
#  'discontinuation',
#  'resolution',
#  'class',
#  'unlockables',
#  'copyrighted',
#  'cabricogirl',
#  'gumi',
#  'garden',
#  'standing',
#  'noun',
#  'crunching',
#  'youga',
#  'aolapp',
#  'trap',
#  'stotage',
#  'betterthis',
#  'wasteful',
#  'kissandfly',
#  'notify',
#  'treating',
#  'scary',
#  'dowloaded',
#  '8getting',
#  '«',
#  'uniformed',
#  'timehave',
#  'household',
#  'artificer',
#  'isolated',
#  'ist',
#  'cellulitis',
#  'dime',
#  'creditringtone',
#  'hasnt',
#  'dragon',
#  'watched',
#  'irrelevant',
#  'aboutconfigs',
#  '3440',
#  'zocdoc',
#  'unberhaubt',
#  'relaunched',
#  'probs',
#  'braungardt',
#  'partnot',
#  '650',
#  'dichotomous',
#  'partner',
#  'season',
#  'keto',
#  'ourocard',
#  'menuand',
#  'mkv',
#  'unrecoverable',
#  'ronaldo',
#  'ar',
#  'abolish',
#  'calendartimetable',
#  'malaysianand',
#  'chad',
#  'mths',
#  'lined',
#  'ak47',
#  'ethink',
#  'condiment',
#  ...}

# %% [markdown]
# Then for each data point (tokens with the pos/neg tag), we will build a dictionary that says whether it has particular features/ words from the vocabulary.

# %%
def features_with_labels(row):
    return ({i:(i in row["Review"]) for i in vocabulary}, row["Sentiment"])

features = x_train.progress_apply(features_with_labels, axis=1)
# Out:
# 100%|██████████| 5598/5598 [28:59<00:00,  3.22it/s]

# %%
classifier = NaiveBayesClassifier.train(features)

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                      lov = True           Positi : Neutra =     48.5 : 1.0
#                     love = True           Positi : Neutra =     47.2 : 1.0
#                    great = True           Positi : Neutra =     42.4 : 1.0
#                     easy = True           Positi : Neutra =     39.8 : 1.0
#                     nice = True           Positi : Neutra =     22.2 : 1.0
#                      gre = True           Positi : Neutra =     18.4 : 1.0
#                      hop = True           Positi : Neutra =     18.3 : 1.0
#                     good = True           Positi : Neutra =     17.9 : 1.0
#                      lem = True           Negati : Neutra =     17.8 : 1.0
#                 horrible = True           Negati : Positi =     17.6 : 1.0

# %%
def features(row):
    return {i:(i in row["Review"]) for i in vocabulary}

test_features = x_test.progress_apply(features,axis=1)
# Out:
#  72%|███████▏  | 16024/22396 [37:36<14:46,  7.19it/s]

# %% [markdown]
# Using the same analyzer, we can also obtain the subjectivity for each review.
